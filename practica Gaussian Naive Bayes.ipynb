# %% [markdown]
# # Ejercicio Machine Learning: Gaussian Naive Bayes

# %% [markdown]
# # Sergio Mauricio Cruz Rosales No. 15111551

# %% [markdown]
# ## Comprar o rentar casa? Cual convendra?

# %% [markdown]
# En este ejercicio, usamos el algoritmo Gaussian Naive Bayes para determinar si conviene adquirir un credito hipotecario para comprar una casa o conveniente retar una casa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sb

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,9)
plt.style.use('ggplot')

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.feature_selection import SelectKBest

# %% [markdown]
# # Damos entrada al conjunto de datos

# %%
dataframe = pd.read_csv('comprar_alquilar.csv')
dataframe.head(10)
# Out:
#    ingresos  gastos_fijos  pago_auto  gastos_otros  ahorros  vivienda  \
# 0      6000          1000          0           600    50000    400000
# 1      6745           944        123           429    43240    636897
# 2      6455          1033         98           795    57463    321779
# 3      7098          1278         15           254    54506    660933
# 4      6167           863        223           520    41512    348932
# 5      5692           911         11           325    50875    360863
# 6      6830          1298        345           309    46761    429812
# 7      6470          1035         39           782    57439    606291
# 8      6251          1250        209           571    50503    291010
# 9      6987          1258        252           245    40611    324098
#
#    estado_civil  hijos  trabajo  comprar
# 0             0      2        2        1
# 1             1      3        6        0
# 2             2      1        8        1
# 3             0      0        3        0
# 4             0      0        3        1
# 5             1      4        5        1
# 6             1      1        5        1
# 7             0      0        1        0
# 8             0      0        3        1
# 9             2      1        7        1

# %% [markdown]
# REFERENCIAS:
# ingresos y gastos mensuales de quienes pagarian el prestamo hipotecario
# trabajo: 0-sin trabajo 1-autonomo 2-asalariado 3-empresario 4-Autonomos 5-Asalariados 6-Autonomo y Asalariado 7-Empresario y Autonomo 8 Empresarios o empresario y autónomo
# estado_civil: 0-soltero 1-casado 2-indefinido
# hijos: Cantidad de dependientes
# comprar: 0-mejor alquilar 1-Comprar casa
# hipoteca fija a 30 años con interes

# %%
dataframe.drop(['comprar'], axis=1).hist()
plt.show()

# %% [markdown]
# ### Prepocesamos los datos

# %% [markdown]
# Se anexan 2 atributos nuevos. Uno de gastos el cual representa los gastos mensuales y el otro de financiar el cual representa el monto posible del credito.

# %%
dataframe['finaciar']=dataframe['vivienda']-dataframe['ahorros']
dataframe.drop(['gastos_fijos','gastos_otros','pago_auto'],axis=1).head(10)
# Out:
#    ingresos  ahorros  vivienda  estado_civil  hijos  trabajo  comprar  \
# 0      6000    50000    400000             0      2        2        1
# 1      6745    43240    636897             1      3        6        0
# 2      6455    57463    321779             2      1        8        1
# 3      7098    54506    660933             0      0        3        0
# 4      6167    41512    348932             0      0        3        1
# 5      5692    50875    360863             1      4        5        1
# 6      6830    46761    429812             1      1        5        1
# 7      6470    57439    606291             0      0        1        0
# 8      6251    50503    291010             0      0        3        1
# 9      6987    40611    324098             2      1        7        1
#
#    finaciar
# 0    350000
# 1    593657
# 2    264316
# 3    606427
# 4    307420
# 5    309988
# 6    383051
# 7    548852
# 8    240507
# 9    283487

# %% [markdown]
# # Estadistica descriptiva de los datos

# %%
reduced = dataframe.drop(['gastos_fijos','gastos_otros','pago_auto'],axis=1)
reduced.describe()
# Out:
#           ingresos       ahorros       vivienda  estado_civil       hijos  \
# count   202.000000    202.000000     202.000000    202.000000  202.000000
# mean   4958.995050  38749.668317  373349.638614      1.024752    1.232673
# std    1682.862556  17365.231870  136371.525622      0.837184    1.367833
# min    2008.000000  10319.000000  176553.000000      0.000000    0.000000
# 25%    3513.750000  24964.250000  274810.000000      0.000000    0.000000
# 50%    4947.500000  38523.000000  340783.500000      1.000000    1.000000
# 75%    6374.500000  52150.750000  444482.000000      2.000000    2.000000
# max    7984.000000  69934.000000  669540.000000      2.000000    4.000000
#
#           trabajo     comprar       finaciar
# count  202.000000  202.000000     202.000000
# mean     4.490099    0.331683  334599.970297
# std      2.535794    0.471988  126607.099497
# min      0.000000    0.000000  154716.000000
# 25%      2.000000    0.000000  240410.250000
# 50%      5.000000    0.000000  301177.000000
# 75%      7.000000    1.000000  393413.000000
# max      8.000000    1.000000  618621.000000

# %% [markdown]
# # Seleccion de atributos carateristicos de entrada (Feature Selection)

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sb.heatmap(reduced.astype(float).corr(),linewidth=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %% [markdown]
# Se utliza clase SelectKBest de SKLearn para seleccionar las 5 mejores caracteristicas

# %%
x = dataframe.drop(['comprar'], axis=1)
y = dataframe['comprar']

best = SelectKBest(k=5)
x_new = best.fit_transform(x,y)
x_new.shape
selected = best.get_support(indices=True)
print(x.columns[selected])
# Out:
# Index(['ingresos', 'gastos_fijos', 'ahorros', 'hijos', 'trabajo'], dtype='object')

# %% [markdown]
# se visualiza la correciones entre las 5 caracteristicas seleccionadas

# %%
used_features = x.columns[selected]
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Person Correlation of Features', y=1.05, size=15)
sb.heatmap(dataframe[used_features].astype(float).corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)

# %%
sb.pairplot(dataframe, hue='comprar', height=4, vars=used_features, kind='scatter')

# %% [markdown]
# ## Ejemplo: Grafica 2 de las caracteristicas

# %%
used_features2 =[
    "ingresos",
    "financiar"
]
X=dataframe[used_features2].values
y=dataframe["comprar"]

fig, ax = plt.subplots()

ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='RdBu')
ax.set_title('Naive Bayes Model', size=14)

xlim = (2000, 9000)
ylim = (100000, 700000)

xg = np.linspace(xlim[0], xlim[1], 40)
yg = np.linspace(ylim[0], ylim[1], 30)
xx, yy = np.meshgrid(xg, yg)
Xgrid = np.vstack([xx.ravel(), yy.ravel()]).T

for label, color in enumerate(['red', 'blue']):
    mask = (y == label)
    mu, std = X[mask].mean(0), X[mask].std(0)
    P = np.exp(-0.5 * (Xgrid - mu) * 2 / std * 2).prod(1)
    Pm = np.ma.masked_array(P, P < 0.03)
    ax.pcolorfast(xg, yg, Pm.reshape(xx.shape), alpha=0.5,
                  cmap=color.title() + 's')
    ax.contour(xx, yy, P.reshape(xx.shape),
               levels=[0.01, 0.1, 0.5, 0.9],
               colors=color, alpha=0.2)
    
ax.set(xlim=xlim, ylim=ylim)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-cbbd63d5f5d6> in <module>
#       3     "financiar"
#       4 ]
# ----> 5 X=dataframe[used_features2].values
#       6 y=dataframe["comprar"]
#       7
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['financiar'] not in index"

# %% [markdown]
# se aprecia que una cantidad mayor de ingreso y una cantidad menor de finaciamiento es mejor la opcion de comprar la casa(en azul). De otra comvendra rentar(en rojo)

# %% [markdown]
# # Obtencion del modelo de Gaussian Naive Bayes

# %% [markdown]
# Se divide un set de entrenamiento y otro de test con 25% de entrada

# %%
x_train, x_test = train_test_split(dataframe, test_size=0.25,random_state=6)
y_train = x_train['comprar']
y_test=x_test['comprar']

# %%
# Entrenamos al modelo
# Iniciamos el clasificador
gnb = GaussianNB()
# Entrenar al clasificador
gnb.fit(
    x_train[used_features].values,
    y_train
)
y_pred = gnb.predict(x_test[used_features])

# %%
print('Precision del conjunto de entrenamiento: {:.2f}'
     .format(gnb.score(x_train[used_features], y_train)))
print('Precision del conjunto de prueba: {:.2f}'
     .format(gnb.score(x_test[used_features], y_test)))
# Out:
# Precision del conjunto de entrenamiento: 0.79
# Precision del conjunto de prueba: 0.88

# %%
print('Total de muestras probadas: {}\nFallos: {}'
      .format(
          x_test.shape[0],
          (y_test != y_pred).sum()
      ))
# Out:
# Total de muestras probadas: 51
# Fallos: 6

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[28  3]
#  [ 3 17]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        31
#            1       0.85      0.85      0.85        20
#
#     accuracy                           0.88        51
#    macro avg       0.88      0.88      0.88        51
# weighted avg       0.88      0.88      0.88        51

# %% [markdown]
# # Nuevas predicciones

# %% [markdown]
# Realizamos 2 pruebas en las que el algoritmo recomiendo rentar(0) y comprar(1)

# %%
#               ['Ingresos','Ahorros', 'Hijos', 'trabajos', 'finaciar']
print(gnb.predict([[2000,     5000,      0,         5,       200000],
                   [6000,     34000,     2,         5,       320000]]))
# Out:
# [0 0]
